# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Import Openweather
import openweathermapy.core as owm

# progress bar
from tqdm import tqdm_notebook

# Output File (CSV)
output_data_file = "output_data/cities.csv"


# output for image
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 636

# %%
#check cities
cities[0:15]
# Out:
# ['netarhat',
#  'thompson',
#  'sitka',
#  'west wendover',
#  'coquimbo',
#  'luwuk',
#  'krasnoarmeysk',
#  'bluff',
#  'peniche',
#  'belushya guba',
#  'port alfred',
#  'lichuan',
#  'labuhan',
#  'banes',
#  'longyearbyen']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# create data array
city_weather = []
store_index  = []
store_cityName = []
store_city_not_found = []
count_city_not_found = 0  # count number of cities not found

# transform cities into datframe for the progress bar
cities_df = pd.DataFrame(cities,columns=['city'])

cities_df.head()
# Out:
#             city
# 0       netarhat
# 1       thompson
# 2          sitka
# 3  west wendover
# 4       coquimbo

# %%
city_weather = []
store_index  = []
store_cityName = []
store_city_not_found = []
count_city_not_found = 0  # count number of cities not found

# Parameters to split df into sets to avoid pulling too much data from API and get the API key blocked
ncity = len(cities) # total number of cities
step  = 50          # number city for set
nloop = int (ncity/step) +1  # total number of sets

count_city_not_found = 0  # count cities not found
count_city_found = 0      # count cities found
iset = 0                  # set set index to 0



for index, row in tqdm_notebook(list(cities_df.iterrows())): # add progress bar for fun
    if (0 == index):  # Display for the first data only
        print("Beginning Data Retrieval ")
        print("-----------------------------")
        
    if (index > step & 0 == (index%step) ):  # Increase istep at the end of iset 
        iset = iset +1
        time.sleep(15)   # Pause to avoid pulling too much data
    try:      # access to API and get data 
        city_weather.append(owm.get_current(cities_df.loc[index, 'city'], **settings))
               
        if (0 == (index%step)):  # Text for the first data of each set
            print(f"Processing Record {0} of set {iset+1} | {cities_df.loc[index, 'city']}")
        else:   # Text for the other data of each set
            print(f"Processing Record {index-(iset*step)} of set {iset+1} | {cities_df.loc[index, 'city']}") 
        count_city_found = count_city_found+1
                  
    except:  # catch error to avoid code crash    
        store_city_not_found.append(cities_df.loc[index, 'city'])
        count_city_not_found = count_city_not_found +1
        print(f"{cities_df.loc[index, 'city']} not found")

              
# Print ending message
print("-----------------------------")      
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# HBox(children=(IntProgress(value=0, max=636), HTML(value='')))
# Processing Record 0 of set 1 | netarhat
# Processing Record 1 of set 1 | thompson
# Processing Record 2 of set 1 | sitka
# Processing Record 3 of set 1 | west wendover
# Processing Record 4 of set 1 | coquimbo
# Processing Record 5 of set 1 | luwuk
# Processing Record 6 of set 1 | krasnoarmeysk
# Processing Record 7 of set 1 | bluff
# Processing Record 8 of set 1 | peniche
# belushya guba not found
# Processing Record 10 of set 1 | port alfred
# Processing Record 11 of set 1 | lichuan
# Processing Record 12 of set 1 | labuhan
# Processing Record 13 of set 1 | banes
# Processing Record 14 of set 1 | longyearbyen
# Processing Record 15 of set 1 | aleksandrovsk-sakhalinskiy
# Processing Record 16 of set 1 | new norfolk
# barentsburg not found
# Processing Record 18 of set 1 | carnarvon
# Processing Record 19 of set 1 | comodoro rivadavia
# Processing Record 20 of set 1 | mataura
# Processing Record 21 of set 1 | east london
# Processing Record 22 of set 1 | bhaderwah
# Processing Record 23 of set 1 | parana
# palabuhanratu not found
# Processing Record 25 of set 1 | whitehorse
# Processing Record 26 of set 1 | punta arenas
# yanan not found
# Processing Record 28 of set 1 | busselton
# Processing Record 29 of set 1 | klyuchi
# Processing Record 30 of set 1 | norman wells
# Processing Record 31 of set 1 | tasiilaq
# Processing Record 32 of set 1 | komsomolskiy
# Processing Record 33 of set 1 | avarua
# bengkulu not found
# Processing Record 35 of set 1 | rikitea
# Processing Record 36 of set 1 | rosario
# Processing Record 37 of set 1 | constantine
# Processing Record 38 of set 1 | nyurba
# Processing Record 39 of set 1 | staryy nadym
# Processing Record 40 of set 1 | hithadhoo
# taolanaro not found
# Processing Record 42 of set 1 | aklavik
# Processing Record 43 of set 1 | arraial do cabo
# Processing Record 44 of set 1 | ancud
# Processing Record 45 of set 1 | zhigansk
# Processing Record 46 of set 1 | ushuaia
# Processing Record 47 of set 1 | talnakh
# Processing Record 48 of set 1 | mahebourg
# Processing Record 49 of set 1 | hobart
# Processing Record 0 of set 2 | belyy yar
# Processing Record 1 of set 2 | lebu
# Processing Record 2 of set 2 | mayo
# Processing Record 3 of set 2 | melipilla
# Processing Record 4 of set 2 | dubbo
# Processing Record 5 of set 2 | muri
# Processing Record 6 of set 2 | salalah
# Processing Record 7 of set 2 | puerto ayora
# Processing Record 8 of set 2 | albany
# Processing Record 9 of set 2 | barrow
# Processing Record 10 of set 2 | saint george
# raga not found
# Processing Record 12 of set 2 | seoul
# Processing Record 13 of set 2 | cherskiy
# Processing Record 14 of set 2 | hermanus
# Processing Record 15 of set 2 | westerland
# Processing Record 16 of set 2 | victoria
# Processing Record 17 of set 2 | kaitangata
# Processing Record 18 of set 2 | morant bay
# Processing Record 19 of set 2 | port keats
# Processing Record 20 of set 2 | chuy
# Processing Record 21 of set 2 | guerrero negro
# Processing Record 22 of set 2 | saint-philippe
# Processing Record 23 of set 2 | butaritari
# Processing Record 24 of set 2 | simpang
# Processing Record 25 of set 2 | provideniya
# Processing Record 26 of set 2 | hilo
# Processing Record 27 of set 2 | jiwani
# Processing Record 28 of set 2 | codrington
# fevralsk not found
# Processing Record 30 of set 2 | khatanga
# Processing Record 31 of set 2 | chino valley
# yomitan not found
# Processing Record 33 of set 2 | narsingi
# Processing Record 34 of set 2 | acari
# Processing Record 35 of set 2 | smithers
# Processing Record 36 of set 2 | kapaa
# Processing Record 37 of set 2 | sioux lookout
# Processing Record 38 of set 2 | ayan
# Processing Record 39 of set 2 | ochamchira
# Processing Record 40 of set 2 | saskylakh
# Processing Record 41 of set 2 | panacan
# Processing Record 42 of set 2 | ust-donetskiy
# Processing Record 43 of set 2 | berlevag
# attawapiskat not found
# tsihombe not found
# Processing Record 46 of set 2 | dikson
# Processing Record 47 of set 2 | phan thiet
# amderma not found
# Processing Record 49 of set 2 | ostrovnoy
# Processing Record 0 of set 3 | amalapuram
# Processing Record 1 of set 3 | cidreira
# kuche not found
# Processing Record 3 of set 3 | carballo
# Processing Record 4 of set 3 | mayskiy
# Processing Record 5 of set 3 | taoudenni
# Processing Record 6 of set 3 | erzin
# Processing Record 7 of set 3 | hirado
# wahran not found
# Processing Record 9 of set 3 | thinadhoo
# Processing Record 10 of set 3 | port blair
# Processing Record 11 of set 3 | saint-leu
# Processing Record 12 of set 3 | vaini
# Processing Record 13 of set 3 | bethel
# Processing Record 14 of set 3 | tual
# Processing Record 15 of set 3 | porto novo
# Processing Record 16 of set 3 | pangnirtung
# Processing Record 17 of set 3 | simiti
# Processing Record 18 of set 3 | pandan
# samusu not found
# Processing Record 20 of set 3 | jiuquan
# Processing Record 21 of set 3 | georgetown
# Processing Record 22 of set 3 | kruisfontein
# Processing Record 23 of set 3 | airai
# Processing Record 24 of set 3 | ridgecrest
# mys shmidta not found
# Processing Record 26 of set 3 | chokurdakh
# Processing Record 27 of set 3 | vinstra
# Processing Record 28 of set 3 | leshukonskoye
# Processing Record 29 of set 3 | quatre cocos
# chagda not found
# Processing Record 31 of set 3 | isangel
# Processing Record 32 of set 3 | matay
# Processing Record 33 of set 3 | vestmanna
# Processing Record 34 of set 3 | lasa
# karaul not found
# Processing Record 36 of set 3 | saint-pierre
# Processing Record 37 of set 3 | cerkezkoy
# Processing Record 38 of set 3 | ribeira grande
# Processing Record 39 of set 3 | jalingo
# Processing Record 40 of set 3 | goderich
# Processing Record 41 of set 3 | brae
# Processing Record 42 of set 3 | tiksi
# Processing Record 43 of set 3 | pevek
# Processing Record 44 of set 3 | atasu
# Processing Record 45 of set 3 | alzey
# Processing Record 46 of set 3 | xai-xai
# Processing Record 47 of set 3 | doka
# Processing Record 48 of set 3 | marsa matruh
# Processing Record 49 of set 3 | meulaboh
# Processing Record 0 of set 4 | bambous virieux
# Processing Record 1 of set 4 | kinablangan
# Processing Record 2 of set 4 | bandarbeyla
# Processing Record 3 of set 4 | bredasdorp
# Processing Record 4 of set 4 | nouadhibou
# Processing Record 5 of set 4 | upernavik
# Processing Record 6 of set 4 | bose
# Processing Record 7 of set 4 | nome
# Processing Record 8 of set 4 | torbay
# Processing Record 9 of set 4 | clyde river
# Processing Record 10 of set 4 | savannah bight
# Processing Record 11 of set 4 | mende
# Processing Record 12 of set 4 | kavaratti
# Processing Record 13 of set 4 | cabedelo
# Processing Record 14 of set 4 | ponta do sol
# Processing Record 15 of set 4 | tuktoyaktuk
# rungata not found
# Processing Record 17 of set 4 | tautira
# Processing Record 18 of set 4 | saldanha
# Processing Record 19 of set 4 | cagliari
# Processing Record 20 of set 4 | honningsvag
# Processing Record 21 of set 4 | alyangula
# Processing Record 22 of set 4 | esperance
# Processing Record 23 of set 4 | te anau
# Processing Record 24 of set 4 | santa barbara
# Processing Record 25 of set 4 | namatanai
# Processing Record 26 of set 4 | richards bay
# Processing Record 27 of set 4 | havre-saint-pierre
# tuggurt not found
# Processing Record 29 of set 4 | kasongo-lunda
# Processing Record 30 of set 4 | athabasca
# Processing Record 31 of set 4 | fortuna
# Processing Record 32 of set 4 | nikolskoye
# Processing Record 33 of set 4 | requena
# Processing Record 34 of set 4 | gainesville
# Processing Record 35 of set 4 | champerico
# Processing Record 36 of set 4 | daru
# Processing Record 37 of set 4 | vasilsursk
# Processing Record 38 of set 4 | yar-sale
# illoqqortoormiut not found
# Processing Record 40 of set 4 | itarema
# Processing Record 41 of set 4 | jieshi
# Processing Record 42 of set 4 | qaanaaq
# Processing Record 43 of set 4 | robertsport
# Processing Record 44 of set 4 | cape town
# Processing Record 45 of set 4 | touros
# Processing Record 46 of set 4 | geraldton
# Processing Record 47 of set 4 | saint-prosper
# Processing Record 48 of set 4 | vitim
# Processing Record 49 of set 4 | sao joao da barra
# Processing Record 0 of set 5 | ravar
# Processing Record 1 of set 5 | seymchan
# Processing Record 2 of set 5 | banepa
# Processing Record 3 of set 5 | muros
# Processing Record 4 of set 5 | zyryanka
# Processing Record 5 of set 5 | sao filipe
# Processing Record 6 of set 5 | axim
# Processing Record 7 of set 5 | mar del plata
# Processing Record 8 of set 5 | anisoc
# Processing Record 9 of set 5 | san patricio
# grand river south east not found
# Processing Record 11 of set 5 | castro
# Processing Record 12 of set 5 | constitucion
# Processing Record 13 of set 5 | luanda
# Processing Record 14 of set 5 | faanui
# Processing Record 15 of set 5 | luderitz
# Processing Record 16 of set 5 | wattegama
# Processing Record 17 of set 5 | turukhansk
# Processing Record 18 of set 5 | siay
# Processing Record 19 of set 5 | abu samrah
# Processing Record 20 of set 5 | yellowknife
# tingrela not found
# Processing Record 22 of set 5 | berdigestyakh
# Processing Record 23 of set 5 | tiznit
# Processing Record 24 of set 5 | aden
# Processing Record 25 of set 5 | laguna
# Processing Record 26 of set 5 | tuatapere
# saleaula not found
# Processing Record 28 of set 5 | kudahuvadhoo
# Processing Record 29 of set 5 | aragarcas
# kamenskoye not found
# Processing Record 31 of set 5 | vazhiny
# Processing Record 32 of set 5 | half moon bay
# Processing Record 33 of set 5 | atuona
# puerto pinasco not found
# Processing Record 35 of set 5 | aykhal
# Processing Record 36 of set 5 | ahipara
# Processing Record 37 of set 5 | greeley
# Processing Record 38 of set 5 | odienne
# Processing Record 39 of set 5 | jamestown
# Processing Record 40 of set 5 | broome
# Processing Record 41 of set 5 | college
# Processing Record 42 of set 5 | senneterre
# Processing Record 43 of set 5 | lyuban
# Processing Record 44 of set 5 | killarney
# Processing Record 45 of set 5 | leningradskiy
# Processing Record 46 of set 5 | shakawe
# Processing Record 47 of set 5 | kungurtug
# kemijarvi not found
# Processing Record 49 of set 5 | amritsar
# Processing Record 0 of set 6 | rawson
# tahta not found
# Processing Record 2 of set 6 | poum
# Processing Record 3 of set 6 | katima mulilo
# Processing Record 4 of set 6 | yumen
# Processing Record 5 of set 6 | mattru
# Processing Record 6 of set 6 | kant
# Processing Record 7 of set 6 | ati
# Processing Record 8 of set 6 | worthington
# xadani not found
# Processing Record 10 of set 6 | san cristobal
# Processing Record 11 of set 6 | megion
# Processing Record 12 of set 6 | iqaluit
# Processing Record 13 of set 6 | kodiak
# Processing Record 14 of set 6 | grindavik
# Processing Record 15 of set 6 | olkhovatka
# Processing Record 16 of set 6 | barsi
# Processing Record 17 of set 6 | scarborough
# achisay not found
# Processing Record 19 of set 6 | vila velha
# Processing Record 20 of set 6 | palora
# Processing Record 21 of set 6 | cabo san lucas
# Processing Record 22 of set 6 | russell
# Processing Record 23 of set 6 | sayat
# Processing Record 24 of set 6 | la ciotat
# Processing Record 25 of set 6 | sonoita
# meyungs not found
# Processing Record 27 of set 6 | pouebo
# marcona not found
# Processing Record 29 of set 6 | tessalit
# Processing Record 30 of set 6 | gat
# Processing Record 31 of set 6 | natal
# Processing Record 32 of set 6 | traralgon
# Processing Record 33 of set 6 | leh
# Processing Record 34 of set 6 | ponot
# Processing Record 35 of set 6 | nilanga
# Processing Record 36 of set 6 | necochea
# Processing Record 37 of set 6 | marsabit
# Processing Record 38 of set 6 | vieux-habitants
# Processing Record 39 of set 6 | castanos
# Processing Record 40 of set 6 | harper
# sentyabrskiy not found
# Processing Record 42 of set 6 | bratsk
# Processing Record 43 of set 6 | kieta
# doctor pedro p. pena not found
# Processing Record 45 of set 6 | aquiraz
# Processing Record 46 of set 6 | namibe
# bolungarvik not found
# Processing Record 48 of set 6 | yulara
# Processing Record 49 of set 6 | bathsheba
# Processing Record 0 of set 7 | guadalupe
# Processing Record 1 of set 7 | hanzhong
# korla not found
# Processing Record 3 of set 7 | arlit
# Processing Record 4 of set 7 | kaili
# Processing Record 5 of set 7 | bara
# Processing Record 6 of set 7 | karasjok
# Processing Record 7 of set 7 | lompoc
# Processing Record 8 of set 7 | sarkand
# Processing Record 9 of set 7 | hobyo
# Processing Record 10 of set 7 | vagur
# Processing Record 11 of set 7 | mezen
# Processing Record 12 of set 7 | ayorou
# Processing Record 13 of set 7 | port elizabeth
# vaitupu not found
# Processing Record 15 of set 7 | vila franca do campo
# Processing Record 16 of set 7 | kamloops
# bargal not found
# Processing Record 18 of set 7 | severo-kurilsk
# Processing Record 19 of set 7 | key west
# Processing Record 20 of set 7 | kavieng
# Processing Record 21 of set 7 | mackay
# Processing Record 22 of set 7 | susanville
# Processing Record 23 of set 7 | xiaoshan
# Processing Record 24 of set 7 | hasaki
# Processing Record 25 of set 7 | kihei
# Processing Record 26 of set 7 | kailua
# stornoway not found
# hihifo not found
# Processing Record 29 of set 7 | placido de castro
# Processing Record 30 of set 7 | kathmandu
# Processing Record 31 of set 7 | port hedland
# Processing Record 32 of set 7 | ngunguru
# Processing Record 33 of set 7 | hofn
# Processing Record 34 of set 7 | songjianghe
# Processing Record 35 of set 7 | mikhaylovskoye
# Processing Record 36 of set 7 | hami
# Processing Record 37 of set 7 | la ronge
# Processing Record 38 of set 7 | vinukonda
# Processing Record 39 of set 7 | padang
# Processing Record 40 of set 7 | beringovskiy
# Processing Record 41 of set 7 | chulman
# Processing Record 42 of set 7 | entre rios
# Processing Record 43 of set 7 | coihaique
# Processing Record 44 of set 7 | srostki
# Processing Record 45 of set 7 | kisangani
# Processing Record 46 of set 7 | san jeronimo
# Processing Record 47 of set 7 | lathi
# pilao arcado not found
# Processing Record 49 of set 7 | galveston
# Processing Record 0 of set 8 | assiniboia
# Processing Record 1 of set 8 | yanam
# Processing Record 2 of set 8 | buchanan
# Processing Record 3 of set 8 | barkhan
# Processing Record 4 of set 8 | sibolga
# Processing Record 5 of set 8 | amet
# Processing Record 6 of set 8 | new richmond
# Processing Record 7 of set 8 | kirakira
# Processing Record 8 of set 8 | caravelas
# Processing Record 9 of set 8 | kambia
# Processing Record 10 of set 8 | sur
# Processing Record 11 of set 8 | sabha
# Processing Record 12 of set 8 | otane
# Processing Record 13 of set 8 | coswig
# Processing Record 14 of set 8 | millinocket
# Processing Record 15 of set 8 | san ignacio
# Processing Record 16 of set 8 | portland
# nguiu not found
# Processing Record 18 of set 8 | aksarka
# Processing Record 19 of set 8 | mitchell
# Processing Record 20 of set 8 | changji
# Processing Record 21 of set 8 | teguise
# urumqi not found
# Processing Record 23 of set 8 | shimoda
# Processing Record 24 of set 8 | bubaque
# Processing Record 25 of set 8 | tura
# Processing Record 26 of set 8 | saint anthony
# pemangkat not found
# Processing Record 28 of set 8 | ponta delgada
# Processing Record 29 of set 8 | cadillac
# Processing Record 30 of set 8 | eyl
# Processing Record 31 of set 8 | karasburg
# Processing Record 32 of set 8 | inhambane
# Processing Record 33 of set 8 | pisco
# Processing Record 34 of set 8 | michigan city
# Processing Record 35 of set 8 | kumba
# Processing Record 36 of set 8 | banda aceh
# Processing Record 37 of set 8 | vostok
# Processing Record 38 of set 8 | mandalgovi
# Processing Record 39 of set 8 | zabol
# Processing Record 40 of set 8 | grand-santi
# Processing Record 41 of set 8 | prabumulih
# Processing Record 42 of set 8 | mastic beach
# Processing Record 43 of set 8 | saint-augustin
# Processing Record 44 of set 8 | noumea
# Processing Record 45 of set 8 | kargasok
# Processing Record 46 of set 8 | kem
# Processing Record 47 of set 8 | tsumeb
# Processing Record 48 of set 8 | santiago del estero
# Processing Record 49 of set 8 | obo
# Processing Record 0 of set 9 | dakar
# Processing Record 1 of set 9 | portlethen
# karakendzha not found
# Processing Record 3 of set 9 | vaitape
# Processing Record 4 of set 9 | mehran
# Processing Record 5 of set 9 | verkhnyaya toyma
# Processing Record 6 of set 9 | kitami
# chengmai not found
# Processing Record 8 of set 9 | atbasar
# Processing Record 9 of set 9 | teeli
# Processing Record 10 of set 9 | blagoyevo
# Processing Record 11 of set 9 | clonakilty
# Processing Record 12 of set 9 | dingle
# Processing Record 13 of set 9 | cassia
# zachagansk not found
# domoni not found
# Processing Record 16 of set 9 | iskateley
# Processing Record 17 of set 9 | sao miguel do araguaia
# Processing Record 18 of set 9 | ak-dovurak
# burica not found
# Processing Record 20 of set 9 | dunedin
# Processing Record 21 of set 9 | marawi
# Processing Record 22 of set 9 | mamallapuram
# andenes not found
# crab hill not found
# Processing Record 25 of set 9 | katete
# Processing Record 26 of set 9 | chernyshevskiy
# Processing Record 27 of set 9 | prince rupert
# Processing Record 28 of set 9 | tarabuco
# Processing Record 29 of set 9 | manzanillo
# Processing Record 30 of set 9 | kindu
# Processing Record 31 of set 9 | maragogi
# Processing Record 32 of set 9 | port macquarie
# Processing Record 33 of set 9 | narasannapeta
# taburi not found
# Processing Record 35 of set 9 | waipawa
# Processing Record 36 of set 9 | witu
# Processing Record 37 of set 9 | kendari
# Processing Record 38 of set 9 | joensuu
# Processing Record 39 of set 9 | jacareacanga
# Processing Record 40 of set 9 | astoria
# Processing Record 41 of set 9 | paamiut
# nizhneyansk not found
# panjwin not found
# Processing Record 44 of set 9 | srednekolymsk
# Processing Record 45 of set 9 | kiruna
# Processing Record 46 of set 9 | bereda
# Processing Record 47 of set 9 | marovoay
# Processing Record 48 of set 9 | mananjary
# Processing Record 49 of set 9 | fukue
# kashi not found
# Processing Record 1 of set 10 | belmonte
# Processing Record 2 of set 10 | biak
# Processing Record 3 of set 10 | poya
# odweyne not found
# bac lieu not found
# Processing Record 6 of set 10 | sangar
# Processing Record 7 of set 10 | piranshahr
# Processing Record 8 of set 10 | lodja
# Processing Record 9 of set 10 | narrabri
# mrirt not found
# Processing Record 11 of set 10 | ha giang
# Processing Record 12 of set 10 | kolyvan
# Processing Record 13 of set 10 | kachug
# Processing Record 14 of set 10 | ilulissat
# Processing Record 15 of set 10 | lorengau
# Processing Record 16 of set 10 | luganville
# Processing Record 17 of set 10 | lazaro cardenas
# Processing Record 18 of set 10 | jiayuguan
# Processing Record 19 of set 10 | grootfontein
# Processing Record 20 of set 10 | kenai
# tlahualilo not found
# Processing Record 22 of set 10 | santa cruz de tenerife
# Processing Record 23 of set 10 | lagoa
# scottsburgh not found
# mahanje not found
# Processing Record 26 of set 10 | jutai
# Processing Record 27 of set 10 | araouane
# Processing Record 28 of set 10 | nanortalik
# Processing Record 29 of set 10 | nago
# Processing Record 30 of set 10 | andoain
# Processing Record 31 of set 10 | tarbagatay
# Processing Record 32 of set 10 | kushima
# Processing Record 33 of set 10 | bima
# Processing Record 34 of set 10 | murwara
# deshna not found
# Processing Record 36 of set 10 | ambalavao
# Processing Record 37 of set 10 | tanabe
# Processing Record 38 of set 10 | bennettsville
# Processing Record 39 of set 10 | derzhavinsk
# Processing Record 40 of set 10 | nelson bay
# toliary not found
# Processing Record 42 of set 10 | denpasar
# Processing Record 43 of set 10 | bilma
# Processing Record 44 of set 10 | bambanglipuro
# Processing Record 45 of set 10 | tonota
# Processing Record 46 of set 10 | barao de melgaco
# Processing Record 47 of set 10 | carutapera
# Processing Record 48 of set 10 | kefalos
# Processing Record 49 of set 10 | rosetown
# Processing Record 0 of set 11 | rocha
# Processing Record 1 of set 11 | knysna
# Processing Record 2 of set 11 | sarishabari
# Processing Record 3 of set 11 | alofi
# Processing Record 4 of set 11 | amasia
# Processing Record 5 of set 11 | grevesmuhlen
# Processing Record 6 of set 11 | sabang
# Processing Record 7 of set 11 | skelleftea
# Processing Record 8 of set 11 | ambilobe
# Processing Record 9 of set 11 | upington
# Processing Record 10 of set 11 | lusambo
# Processing Record 11 of set 11 | verkhoyansk
# Processing Record 12 of set 11 | manakara
# Processing Record 13 of set 11 | broken hill
# Processing Record 14 of set 11 | faya
# Processing Record 15 of set 11 | klaksvik
# barbar not found
# Processing Record 17 of set 11 | lavrentiya
# Processing Record 18 of set 11 | birao
# Processing Record 19 of set 11 | san javier
# Processing Record 20 of set 11 | yantal
# Processing Record 21 of set 11 | cape canaveral
# Processing Record 22 of set 11 | narsaq
# Processing Record 23 of set 11 | takayama
# Processing Record 24 of set 11 | kharitonovo
# Processing Record 25 of set 11 | linxia
# Processing Record 26 of set 11 | dina
# Processing Record 27 of set 11 | graaff-reinet
# Processing Record 28 of set 11 | naryan-mar
# Processing Record 29 of set 11 | miura
# Processing Record 30 of set 11 | tilichiki
# yambio not found
# Processing Record 32 of set 11 | steubenville
# Processing Record 33 of set 11 | hilton head island
# Processing Record 34 of set 11 | nemuro
# Processing Record 35 of set 11 | sumenep
# Processing Record 36 of set 11 | bastia
# Processing Record 37 of set 11 | soimi
# Processing Record 38 of set 11 | najran
# Processing Record 39 of set 11 | souillac
# urdzhar not found
# Processing Record 41 of set 11 | maniitsoq
# Processing Record 42 of set 11 | novoselitskoye
# Processing Record 43 of set 11 | beliator
# Processing Record 44 of set 11 | port lincoln
# Processing Record 45 of set 11 | queanbeyan
# Processing Record 46 of set 11 | valdivia
# Processing Record 47 of set 11 | peleduy
# Processing Record 48 of set 11 | banff
# Processing Record 49 of set 11 | cayenne
# Processing Record 0 of set 12 | laureles
# Processing Record 1 of set 12 | kloulklubed
# Processing Record 2 of set 12 | sarahan
# Processing Record 3 of set 12 | henties bay
# Processing Record 4 of set 12 | ust-kuyga
# Processing Record 5 of set 12 | illintsi
# Processing Record 6 of set 12 | coshocton
# angra not found
# Processing Record 8 of set 12 | kon tum
# Processing Record 9 of set 12 | le port
# Processing Record 10 of set 12 | jimma
# azimur not found
# Processing Record 12 of set 12 | shelburne
# Processing Record 13 of set 12 | manokwari
# Processing Record 14 of set 12 | san policarpo
# sorvag not found
# Processing Record 16 of set 12 | hambantota
# Processing Record 17 of set 12 | lafiagi
# Processing Record 18 of set 12 | rabo de peixe
# Processing Record 19 of set 12 | biskupiec
# yuzhno-yeniseyskiy not found
# Processing Record 21 of set 12 | boden
# Processing Record 22 of set 12 | gobabis
# mentok not found
# Processing Record 24 of set 12 | kadnikov
# Processing Record 25 of set 12 | mecca
# Processing Record 26 of set 12 | tezu
# Processing Record 27 of set 12 | shingu
# Processing Record 28 of set 12 | san rafael
# Processing Record 29 of set 12 | katsuura
# Processing Record 30 of set 12 | itoman
# Processing Record 31 of set 12 | boyolangu
# Processing Record 32 of set 12 | vardo
# Processing Record 33 of set 12 | ornskoldsvik
# Processing Record 34 of set 12 | taksimo
# mutsamudu not found
# Processing Record 36 of set 12 | haines junction
# Processing Record 37 of set 12 | el tocuyo
# tumannyy not found
# Processing Record 39 of set 12 | los llanos de aridane
# Processing Record 40 of set 12 | general roca
# Processing Record 41 of set 12 | port-gentil
# Processing Record 42 of set 12 | nsanje
# Processing Record 43 of set 12 | larap
# Processing Record 44 of set 12 | tonantins
# Processing Record 45 of set 12 | bayangol
# Processing Record 46 of set 12 | sarankhola
# Processing Record 47 of set 12 | jiazi
# santa eulalia del rio not found
# Processing Record 49 of set 12 | lazdijai
# Processing Record 0 of set 13 | barranca
# Processing Record 1 of set 13 | vestmannaeyjar
# Processing Record 2 of set 13 | altamont
# Processing Record 3 of set 13 | north bend
# Processing Record 4 of set 13 | makakilo city
# Processing Record 5 of set 13 | tynda
# Processing Record 6 of set 13 | cordoba
# Processing Record 7 of set 13 | warmbad
# Processing Record 8 of set 13 | husavik
# Processing Record 9 of set 13 | kopavogur
# sataua not found
# Processing Record 11 of set 13 | arica
# bacuit not found
# Processing Record 13 of set 13 | rio claro
# Processing Record 14 of set 13 | guangyuan
# Processing Record 15 of set 13 | naze
# Processing Record 16 of set 13 | plastun
# Processing Record 17 of set 13 | ballina
# Processing Record 18 of set 13 | shubarshi
# Processing Record 19 of set 13 | itacarambi
# Processing Record 20 of set 13 | almeria
# Processing Record 21 of set 13 | hirara
# Processing Record 22 of set 13 | batagay-alyta
# Processing Record 23 of set 13 | nguru
# Processing Record 24 of set 13 | tevriz
# Processing Record 25 of set 13 | miri
# Processing Record 26 of set 13 | mount isa
# Processing Record 27 of set 13 | pinawa
# Processing Record 28 of set 13 | mahon
# Processing Record 29 of set 13 | lata
# Processing Record 30 of set 13 | jasper
# Processing Record 31 of set 13 | kualakapuas
# Processing Record 32 of set 13 | katobu
# Processing Record 33 of set 13 | sao desiderio
# Processing Record 34 of set 13 | yeppoon
# Processing Record 35 of set 13 | weihe
#
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# check number of cities found
count_city_found
# Out:
# 560

# %%
# check number of cities not found
count_city_not_found
# Out:
# 76

# %%
# check number of length of dataframe
cities_df.count()
# Out:
# city    636
# dtype: int64

# %%
# check if all cities were processed (count_city_found + count_city_not_found = length(cities))
count_city_found + count_city_not_found
# Out:
# 636

# %%
# check first data inside city_weather
city_weather[0]
# Out:
# {'coord': {'lon': 84.31, 'lat': 23.45},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 24.1,
#   'pressure': 1002.32,
#   'humidity': 85,
#   'temp_min': 24.1,
#   'temp_max': 24.1,
#   'sea_level': 1002.32,
#   'grnd_level': 915.64},
#  'wind': {'speed': 2.56, 'deg': 187.203},
#  'clouds': {'all': 37},
#  'dt': 1563740636,
#  'sys': {'message': 0.0064,
#   'country': 'IN',
#   'sunrise': 1563752880,
#   'sunset': 1563801000},
#  'timezone': 19800,
#  'id': 1261497,
#  'name': 'Netarhat',
#  'cod': 200}

# %%
# check last data inside city_weather
city_weather[-1]
# Out:
# {'coord': {'lon': 105.33, 'lat': 32.99},
#  'weather': [{'id': 502,
#    'main': 'Rain',
#    'description': 'heavy intensity rain',
#    'icon': '10n'}],
#  'base': 'stations',
#  'main': {'temp': 18.1,
#   'pressure': 1006.5,
#   'humidity': 97,
#   'temp_min': 18.1,
#   'temp_max': 18.1,
#   'sea_level': 1006.5,
#   'grnd_level': 832.47},
#  'wind': {'speed': 3.5, 'deg': 8.369},
#  'rain': {'3h': 20.312},
#  'clouds': {'all': 100},
#  'dt': 1563740879,
#  'sys': {'message': 0.0058,
#   'country': 'CN',
#   'sunrise': 1563746682,
#   'sunset': 1563797108},
#  'timezone': 28800,
#  'id': 7372400,
#  'name': 'Weihe',
#  'cod': 200}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather[0]
# Out:
# {'coord': {'lon': 84.31, 'lat': 23.45},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 24.1,
#   'pressure': 1002.32,
#   'humidity': 85,
#   'temp_min': 24.1,
#   'temp_max': 24.1,
#   'sea_level': 1002.32,
#   'grnd_level': 915.64},
#  'wind': {'speed': 2.56, 'deg': 187.203},
#  'clouds': {'all': 37},
#  'dt': 1563740636,
#  'sys': {'message': 0.0064,
#   'country': 'IN',
#   'sunrise': 1563752880,
#   'sunset': 1563801000},
#  'timezone': 19800,
#  'id': 1261497,
#  'name': 'Netarhat',
#  'cod': 200}

# %%
# extract Temperature, humidity, lat,lon, country, wind speed, date, city,max. temperature
temperature = []
humidity    = []
lat         = []
long        = []
cloudiness  = []
wind_speed  = []
country     = []
dt          = []
city_name   = []

for i in range (count_city_found):
    lat.append(city_weather[i]["coord"]["lat"])
    long.append(city_weather[i]["coord"]["lon"])
    temperature.append(city_weather[i]["main"]["temp_max"])
    humidity.append(city_weather[i]["main"]["humidity"])
    cloudiness.append(city_weather[i]["clouds"]["all"])
    country.append(city_weather[i]["sys"]["country"])
    wind_speed.append(city_weather[i]["wind"]["speed"])
    dt.append(city_weather[i]["dt"])
    city_name.append(city_weather[i]["name"])
print("done")
# Out:
# done

# %%
# Create dataframe from extracted data
weather_data_df = pd.DataFrame({
                     'City' : city_name , 
                     'Cloudiness':cloudiness,
                     'Country':country ,
                     'Date':dt, 
                     'Humidity':humidity, 
                     "Lat":lat, 
                     "Lon":long, 
                     "Max temp": temperature, 
                     "Wind speed":wind_speed 
                    })

weather_data_df.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lon  \
# 0       Netarhat          37      IN  1563740636        85  23.45   84.31
# 1       Thompson          20      CA  1563740637        36  55.74  -97.86
# 2          Sitka          80      US  1563740637        46  37.17  -99.65
# 3  West Wendover           1      US  1563740637        18  40.74 -114.07
# 4       Coquimbo          90      CL  1563740637        87 -29.95  -71.34
#
#    Max temp  Wind speed
# 0     24.10        2.56
# 1     24.00        5.70
# 2     33.33        0.45
# 3     32.00        4.60
# 4     12.00        2.60

# %%
# Save in CVS file 
#  without the Pandas index, but with the header
weather_data_df.to_csv(output_data_file, index=False, header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# extract lat and temp to prepare the plot
x = weather_data_df["Lat"]
y = weather_data_df["Max temp"]

# %%
# check date (dt in Unix time)
dt_format = []
for i in range (count_city_found):
    dt_format.append(datetime.utcfromtimestamp(dt[i]).strftime('%Y-%m-%d %H:%M:%S'))

# %%
# found the date 

dt_format = pd.Series(dt_format) # transform the dt list into serie to use split()

date = []

# extract date in Year-month-day format
for i in range (count_city_found): 
    date.append(dt_format.str.split(" ")[i][0])

# %%
# checl if date is unique
date= pd.Series(date)
day = date.unique()[0]
day
# Out:
# '2019-07-21'

# %%
min_temp = weather_data_df["Max temp"].min()
max_temp = weather_data_df["Max temp"].max()

# %%
round(min_temp/10)*10
# Out:
# 0.0

# %%
# determine the minmax of the temperature axis
margin_temp = 5  # margin value
axis_temp_max = round(max_temp/10)*10 + margin_temp
axis_temp_min = round(min_temp/10)*10 - margin_temp

# %%
plt.scatter(x,y, marker="o", facecolors="lightblue", edgecolors="black", alpha=0.75)
plt.xlim(-90,90)  # range of lat [-90:90]
plt.ylim(axis_temp_min,axis_temp_max)

plt.xlabel("Latitude (deg)")
plt.ylabel("Max. temperature (F)")
plt.grid()

plt.title(f"City Latitude vs Max Temperature ({day})")
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig("../Images/18-final-plot.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
