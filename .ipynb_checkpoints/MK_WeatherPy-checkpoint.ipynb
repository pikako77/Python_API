# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Import Openweather
import openweathermapy.core as owm

# progress bar
from tqdm import tqdm_notebook

# Output File (CSV)
output_data_file = "output_data/cities.csv"
fig_file1 = "plot/lat_temp.png"
fig_file2 = "plot/lat_humidity.png"
fig_file3 = "plot/lat_cloud.png"
fig_file4 = "plot/lat_wind.png"

# output for image
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %%
#check cities
cities[0:15]
# Out:
# ['barentsburg',
#  'barma',
#  'pevek',
#  'isangel',
#  'attawapiskat',
#  'port elizabeth',
#  'busselton',
#  'jardim',
#  'east london',
#  'sentyabrskiy',
#  'ushuaia',
#  'lagoa',
#  'hilo',
#  'panzhihua',
#  'mahebourg']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# create data array
city_weather = []
store_index  = []
store_cityName = []
store_city_not_found = []
count_city_not_found = 0  # count number of cities not found

# transform cities into datframe for the progress bar
cities_df = pd.DataFrame(cities,columns=['city'])

cities_df.head()
# Out:
#            city
# 0   barentsburg
# 1         barma
# 2         pevek
# 3       isangel
# 4  attawapiskat

# %%
city_weather = []
store_index  = []
store_cityName = []
store_city_not_found = []
count_city_not_found = 0  # count number of cities not found

# Parameters to split df into sets to avoid pulling too much data from API and get the API key blocked
ncity = len(cities) # total number of cities
step  = 50          # number city for set
nloop = int (ncity/step) +1  # total number of sets

count_city_not_found = 0  # count cities not found
count_city_found = 0      # count cities found
iset = 0                  # set set index to 0



for index, row in tqdm_notebook(list(cities_df.iterrows())): # add progress bar for fun
    if (0 == index):  # Display for the first data only
        print("Beginning Data Retrieval ")
        print("-----------------------------")
        
    if (index > step & 0 == (index%step) ):  # Increase istep at the end of iset 
        iset = iset +1
        time.sleep(15)   # Pause to avoid pulling too much data
    try:      # access to API and get data 
        city_weather.append(owm.get_current(cities_df.loc[index, 'city'], **settings))
               
        if (0 == (index%step)):  # Text for the first data of each set
            print(f"Processing Record {0} of set {iset+1} | {cities_df.loc[index, 'city']}")
        else:   # Text for the other data of each set
            print(f"Processing Record {index-(iset*step)} of set {iset+1} | {cities_df.loc[index, 'city']}") 
        count_city_found = count_city_found+1
                  
    except:  # catch error to avoid code crash    
        store_city_not_found.append(cities_df.loc[index, 'city'])
        count_city_not_found = count_city_not_found +1
        print(f"{cities_df.loc[index, 'city']} not found")

              
# Print ending message
print("-----------------------------")      
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# HBox(children=(IntProgress(value=0, max=616), HTML(value='')))
# Beginning Data Retrieval
# -----------------------------
# barentsburg not found
# Processing Record 1 of set 1 | barma
# Processing Record 2 of set 1 | pevek
# Processing Record 3 of set 1 | isangel
# attawapiskat not found
# Processing Record 5 of set 1 | port elizabeth
# Processing Record 6 of set 1 | busselton
# Processing Record 7 of set 1 | jardim
# Processing Record 8 of set 1 | east london
# sentyabrskiy not found
# Processing Record 10 of set 1 | ushuaia
# Processing Record 11 of set 1 | lagoa
# Processing Record 12 of set 1 | hilo
# Processing Record 13 of set 1 | panzhihua
# Processing Record 14 of set 1 | mahebourg
# Processing Record 15 of set 1 | hearst
# Processing Record 16 of set 1 | urucara
# Processing Record 17 of set 1 | caravelas
# Processing Record 18 of set 1 | san patricio
# Processing Record 19 of set 1 | thompson
# Processing Record 20 of set 1 | bourail
# Processing Record 21 of set 1 | carutapera
# Processing Record 22 of set 1 | ostersund
# Processing Record 23 of set 1 | tuktoyaktuk
# Processing Record 24 of set 1 | rikitea
# Processing Record 25 of set 1 | noumea
# Processing Record 26 of set 1 | arraial do cabo
# raga not found
# Processing Record 28 of set 1 | rio grande
# Processing Record 29 of set 1 | bredasdorp
# Processing Record 30 of set 1 | pangnirtung
# Processing Record 31 of set 1 | malumfashi
# Processing Record 32 of set 1 | punta arenas
# Processing Record 33 of set 1 | avarua
# Processing Record 34 of set 1 | lorengau
# belushya guba not found
# Processing Record 36 of set 1 | severo-kurilsk
# Processing Record 37 of set 1 | hobart
# Processing Record 38 of set 1 | chuy
# Processing Record 39 of set 1 | assiniboia
# Processing Record 40 of set 1 | jiayuguan
# Processing Record 41 of set 1 | mount gambier
# Processing Record 42 of set 1 | upernavik
# Processing Record 43 of set 1 | sagae
# Processing Record 44 of set 1 | tasiilaq
# Processing Record 45 of set 1 | gryazovets
# Processing Record 46 of set 1 | guerrero negro
# asau not found
# Processing Record 48 of set 1 | kangaatsiaq
# Processing Record 49 of set 1 | renqiu
# Processing Record 0 of set 2 | quatre cocos
# Processing Record 1 of set 2 | nanortalik
# Processing Record 2 of set 2 | saskylakh
# Processing Record 3 of set 2 | marawi
# Processing Record 4 of set 2 | flinders
# vaitupu not found
# Processing Record 6 of set 2 | georgetown
# Processing Record 7 of set 2 | barrow
# Processing Record 8 of set 2 | albany
# Processing Record 9 of set 2 | dano
# la gaulette not found
# Processing Record 11 of set 2 | panjab
# Processing Record 12 of set 2 | vaini
# Processing Record 13 of set 2 | klaksvik
# Processing Record 14 of set 2 | mugumu
# Processing Record 15 of set 2 | tieli
# Processing Record 16 of set 2 | kavieng
# Processing Record 17 of set 2 | bethel
# Processing Record 18 of set 2 | roros
# Processing Record 19 of set 2 | borovo
# Processing Record 20 of set 2 | butaritari
# Processing Record 21 of set 2 | hermanus
# Processing Record 22 of set 2 | noshiro
# Processing Record 23 of set 2 | new norfolk
# Processing Record 24 of set 2 | cape town
# Processing Record 25 of set 2 | kieta
# Processing Record 26 of set 2 | jamestown
# Processing Record 27 of set 2 | rocha
# Processing Record 28 of set 2 | katsuura
# Processing Record 29 of set 2 | chokurdakh
# Processing Record 30 of set 2 | puerto del rosario
# Processing Record 31 of set 2 | carnarvon
# Processing Record 32 of set 2 | provideniya
# andenes not found
# Processing Record 34 of set 2 | saint-pierre
# Processing Record 35 of set 2 | atuona
# Processing Record 36 of set 2 | yar-sale
# Processing Record 37 of set 2 | milkovo
# Processing Record 38 of set 2 | mataura
# Processing Record 39 of set 2 | taunggyi
# Processing Record 40 of set 2 | vangaindrano
# Processing Record 41 of set 2 | marystown
# Processing Record 42 of set 2 | port alfred
# Processing Record 43 of set 2 | palmer
# Processing Record 44 of set 2 | belaya gora
# Processing Record 45 of set 2 | hamilton
# Processing Record 46 of set 2 | airai
# Processing Record 47 of set 2 | karratha
# Processing Record 48 of set 2 | aklavik
# Processing Record 49 of set 2 | rafaela
# Processing Record 0 of set 3 | kasempa
# Processing Record 1 of set 3 | nokha
# Processing Record 2 of set 3 | sayyan
# Processing Record 3 of set 3 | sapele
# Processing Record 4 of set 3 | muros
# Processing Record 5 of set 3 | lebu
# Processing Record 6 of set 3 | kaitangata
# Processing Record 7 of set 3 | horki
# Processing Record 8 of set 3 | touros
# Processing Record 9 of set 3 | dudinka
# Processing Record 10 of set 3 | half moon bay
# Processing Record 11 of set 3 | taoudenni
# Processing Record 12 of set 3 | mar del plata
# Processing Record 13 of set 3 | arkhangelsk
# Processing Record 14 of set 3 | praya
# Processing Record 15 of set 3 | maltahohe
# Processing Record 16 of set 3 | pedernales
# Processing Record 17 of set 3 | norman wells
# Processing Record 18 of set 3 | komsomolets
# lolua not found
# Processing Record 20 of set 3 | bambous virieux
# Processing Record 21 of set 3 | kavaratti
# Processing Record 22 of set 3 | snezhnogorsk
# Processing Record 23 of set 3 | castro
# Processing Record 24 of set 3 | maunabo
# Processing Record 25 of set 3 | hambantota
# Processing Record 26 of set 3 | arani
# Processing Record 27 of set 3 | sur
# Processing Record 28 of set 3 | qaanaaq
# Processing Record 29 of set 3 | savannah bight
# Processing Record 30 of set 3 | sacama
# Processing Record 31 of set 3 | canutama
# phan rang not found
# Processing Record 33 of set 3 | bolshoy lug
# Processing Record 34 of set 3 | karacabey
# Processing Record 35 of set 3 | havelock
# Processing Record 36 of set 3 | faanui
# Processing Record 37 of set 3 | dingle
# Processing Record 38 of set 3 | manaira
# warqla not found
# Processing Record 40 of set 3 | la ronge
# Processing Record 41 of set 3 | oktyabrskoye
# Processing Record 42 of set 3 | saint george
# Processing Record 43 of set 3 | dunedin
# Processing Record 44 of set 3 | takoradi
# Processing Record 45 of set 3 | coahuayana
# Processing Record 46 of set 3 | nefteyugansk
# Processing Record 47 of set 3 | port lincoln
# Processing Record 48 of set 3 | hasaki
# Processing Record 49 of set 3 | pouso alegre
# Processing Record 0 of set 4 | onega
# Processing Record 1 of set 4 | portalegre
# Processing Record 2 of set 4 | bluff
# Processing Record 3 of set 4 | wanganui
# Processing Record 4 of set 4 | najran
# Processing Record 5 of set 4 | dikson
# grand river south east not found
# Processing Record 7 of set 4 | pondicherry
# Processing Record 8 of set 4 | springbok
# Processing Record 9 of set 4 | qaqortoq
# Processing Record 10 of set 4 | mehamn
# amderma not found
# qui nhon not found
# qurayyat not found
# Processing Record 14 of set 4 | villavieja
# Processing Record 15 of set 4 | lahij
# Processing Record 16 of set 4 | coquimbo
# Processing Record 17 of set 4 | wajima
# barawe not found
# Processing Record 19 of set 4 | longyearbyen
# Processing Record 20 of set 4 | shimoda
# illoqqortoormiut not found
# Processing Record 22 of set 4 | talnakh
# Processing Record 23 of set 4 | duminichi
# Processing Record 24 of set 4 | semey
# Processing Record 25 of set 4 | sao miguel do araguaia
# Processing Record 26 of set 4 | hennebont
# Processing Record 27 of set 4 | san luis
# Processing Record 28 of set 4 | gizo
# Processing Record 29 of set 4 | basco
# Processing Record 30 of set 4 | hobyo
# samusu not found
# Processing Record 32 of set 4 | sitka
# Processing Record 33 of set 4 | nikolskoye
# Processing Record 34 of set 4 | sao geraldo do araguaia
# Processing Record 35 of set 4 | pisco
# Processing Record 36 of set 4 | grindavik
# Processing Record 37 of set 4 | saint-philippe
# Processing Record 38 of set 4 | shenkursk
# Processing Record 39 of set 4 | khatanga
# Processing Record 40 of set 4 | pastavy
# Processing Record 41 of set 4 | puerto ayora
# nizhneyansk not found
# Processing Record 43 of set 4 | saint-georges
# Processing Record 44 of set 4 | uthal
# Processing Record 45 of set 4 | tiksi
# Processing Record 46 of set 4 | sosnovo-ozerskoye
# Processing Record 47 of set 4 | antalaha
# tsihombe not found
# Processing Record 49 of set 4 | williamsport
# Processing Record 0 of set 5 | ribeira grande
# Processing Record 1 of set 5 | butiama
# Processing Record 2 of set 5 | ushumun
# Processing Record 3 of set 5 | fallon
# Processing Record 4 of set 5 | nizhniy tsasuchey
# mys shmidta not found
# Processing Record 6 of set 5 | yellowknife
# Processing Record 7 of set 5 | nouakchott
# Processing Record 8 of set 5 | bubaque
# Processing Record 9 of set 5 | key west
# Processing Record 10 of set 5 | kodiak
# Processing Record 11 of set 5 | paso de los toros
# Processing Record 12 of set 5 | loandjili
# Processing Record 13 of set 5 | hami
# Processing Record 14 of set 5 | tiznit
# Processing Record 15 of set 5 | saldanha
# taolanaro not found
# Processing Record 17 of set 5 | neepawa
# Processing Record 18 of set 5 | buriti dos lopes
# Processing Record 19 of set 5 | boa vista
# tokzar not found
# Processing Record 21 of set 5 | ancud
# Processing Record 22 of set 5 | quang ngai
# Processing Record 23 of set 5 | paamiut
# arrecife not found
# Processing Record 25 of set 5 | teguldet
# liminangcong not found
# Processing Record 27 of set 5 | candelaria
# galiwinku not found
# Processing Record 29 of set 5 | tuatapere
# Processing Record 30 of set 5 | rosario
# Processing Record 31 of set 5 | iiyama
# Processing Record 32 of set 5 | mogadishu
# Processing Record 33 of set 5 | santiago de cao
# Processing Record 34 of set 5 | bonavista
# Processing Record 35 of set 5 | sioux lookout
# Processing Record 36 of set 5 | neryungri
# bengkulu not found
# Processing Record 38 of set 5 | cherskiy
# Processing Record 39 of set 5 | mount isa
# Processing Record 40 of set 5 | berlevag
# Processing Record 41 of set 5 | alofi
# Processing Record 42 of set 5 | champerico
# Processing Record 43 of set 5 | abu samrah
# Processing Record 44 of set 5 | chambas
# Processing Record 45 of set 5 | rudsar
# Processing Record 46 of set 5 | fairbanks
# Processing Record 47 of set 5 | rio esteban
# Processing Record 48 of set 5 | pangkalanbuun
# Processing Record 49 of set 5 | araouane
# Processing Record 0 of set 6 | vanimo
# Processing Record 1 of set 6 | bandarbeyla
# Processing Record 2 of set 6 | nalut
# Processing Record 3 of set 6 | mago
# Processing Record 4 of set 6 | kimbe
# Processing Record 5 of set 6 | kapaa
# Processing Record 6 of set 6 | karksi-nuia
# Processing Record 7 of set 6 | cidreira
# Processing Record 8 of set 6 | aksarka
# Processing Record 9 of set 6 | kamiiso
# Processing Record 10 of set 6 | sorland
# Processing Record 11 of set 6 | port hawkesbury
# Processing Record 12 of set 6 | falmouth
# Processing Record 13 of set 6 | kahului
# Processing Record 14 of set 6 | kapit
# Processing Record 15 of set 6 | hithadhoo
# Processing Record 16 of set 6 | dwarka
# Processing Record 17 of set 6 | otavi
# Processing Record 18 of set 6 | nuuk
# Processing Record 19 of set 6 | prince rupert
# Processing Record 20 of set 6 | ca mau
# Processing Record 21 of set 6 | xiuyan
# Processing Record 22 of set 6 | puerto ayacucho
# Processing Record 23 of set 6 | sirnak
# Processing Record 24 of set 6 | samarai
# Processing Record 25 of set 6 | umm lajj
# Processing Record 26 of set 6 | calabozo
# Processing Record 27 of set 6 | muravlenko
# Processing Record 28 of set 6 | crotone
# Processing Record 29 of set 6 | cabo san lucas
# karkaralinsk not found
# Processing Record 31 of set 6 | nemuro
# Processing Record 32 of set 6 | lixourion
# Processing Record 33 of set 6 | chisinau
# Processing Record 34 of set 6 | leh
# Processing Record 35 of set 6 | lokachi
# odweyne not found
# Processing Record 37 of set 6 | sao filipe
# Processing Record 38 of set 6 | roald
# haibowan not found
# utiroa not found
# Processing Record 41 of set 6 | ukiah
# Processing Record 42 of set 6 | amapa
# Processing Record 43 of set 6 | victoria
# Processing Record 44 of set 6 | fortuna
# Processing Record 45 of set 6 | gucheng
# Processing Record 46 of set 6 | salalah
# kushmurun not found
# Processing Record 48 of set 6 | florianopolis
# Processing Record 49 of set 6 | anuradhapura
# Processing Record 0 of set 7 | guarapari
# Processing Record 1 of set 7 | ixtapa
# Processing Record 2 of set 7 | torbay
# Processing Record 3 of set 7 | sobolevo
# Processing Record 4 of set 7 | silver city
# Processing Record 5 of set 7 | lekoni
# Processing Record 6 of set 7 | kununurra
# Processing Record 7 of set 7 | abong mbang
# Processing Record 8 of set 7 | axim
# Processing Record 9 of set 7 | butembo
# Processing Record 10 of set 7 | hameenlinna
# cumaribo not found
# inderborskiy not found
# Processing Record 13 of set 7 | sabha
# Processing Record 14 of set 7 | fuyu
# Processing Record 15 of set 7 | qeshm
# Processing Record 16 of set 7 | pittsfield
# Processing Record 17 of set 7 | ostrovnoy
# Processing Record 18 of set 7 | northam
# tabiauea not found
# Processing Record 20 of set 7 | ilulissat
# Processing Record 21 of set 7 | batemans bay
# Processing Record 22 of set 7 | luderitz
# Processing Record 23 of set 7 | pangoa
# Processing Record 24 of set 7 | niigata
# Processing Record 25 of set 7 | palmerston
# Processing Record 26 of set 7 | padang
# Processing Record 27 of set 7 | constitucion
# Processing Record 28 of set 7 | ponta do sol
# Processing Record 29 of set 7 | bogorodskoye
# Processing Record 30 of set 7 | port hedland
# Processing Record 31 of set 7 | vestmannaeyjar
# Processing Record 32 of set 7 | tawang
# Processing Record 33 of set 7 | jadu
# Processing Record 34 of set 7 | sohag
# vastervik not found
# Processing Record 36 of set 7 | marsh harbour
# Processing Record 37 of set 7 | arman
# Processing Record 38 of set 7 | nara
# Processing Record 39 of set 7 | hohhot
# Processing Record 40 of set 7 | yerbogachen
# Processing Record 41 of set 7 | bocas del toro
# Processing Record 42 of set 7 | luena
# Processing Record 43 of set 7 | lasa
# Processing Record 44 of set 7 | kruisfontein
# Processing Record 45 of set 7 | xining
# Processing Record 46 of set 7 | aasiaat
# Processing Record 47 of set 7 | itarema
# abiy adi not found
# Processing Record 49 of set 7 | durango
# Processing Record 0 of set 8 | buraydah
# Processing Record 1 of set 8 | ponta delgada
# Processing Record 2 of set 8 | fort nelson
# Processing Record 3 of set 8 | kapuskasing
# Processing Record 4 of set 8 | altay
# Processing Record 5 of set 8 | halifax
# Processing Record 6 of set 8 | codrington
# Processing Record 7 of set 8 | namwala
# Processing Record 8 of set 8 | abnub
# Processing Record 9 of set 8 | sinnamary
# Processing Record 10 of set 8 | mangan
# Processing Record 11 of set 8 | kysyl-syr
# Processing Record 12 of set 8 | sangar
# Processing Record 13 of set 8 | faya
# Processing Record 14 of set 8 | labuhan
# Processing Record 15 of set 8 | ouallam
# Processing Record 16 of set 8 | roebourne
# Processing Record 17 of set 8 | katherine
# Processing Record 18 of set 8 | tazovskiy
# Processing Record 19 of set 8 | yumbing
# Processing Record 20 of set 8 | bodden town
# el faiyum not found
# Processing Record 22 of set 8 | anadyr
# Processing Record 23 of set 8 | dhemaji
# Processing Record 24 of set 8 | terrak
# rudbar not found
# Processing Record 26 of set 8 | qasigiannguit
# Processing Record 27 of set 8 | kupino
# Processing Record 28 of set 8 | hofn
# Processing Record 29 of set 8 | khandyga
# Processing Record 30 of set 8 | lungi
# Processing Record 31 of set 8 | cayenne
# bac lieu not found
# Processing Record 33 of set 8 | whitehorse
# Processing Record 34 of set 8 | trincomalee
# Processing Record 35 of set 8 | saint-joseph
# Processing Record 36 of set 8 | emborion
# Processing Record 37 of set 8 | derzhavinsk
# Processing Record 38 of set 8 | geraldton
# Processing Record 39 of set 8 | kirakira
# Processing Record 40 of set 8 | bambanglipuro
# Processing Record 41 of set 8 | yanam
# bargal not found
# Processing Record 43 of set 8 | nome
# Processing Record 44 of set 8 | masaguisi
# ambodifototra not found
# kegayli not found
# Processing Record 47 of set 8 | lebanon
# artyk not found
# Processing Record 49 of set 8 | novikovo
# Processing Record 0 of set 9 | yulara
# Processing Record 1 of set 9 | san fernando
# Processing Record 2 of set 9 | mercedes
# Processing Record 3 of set 9 | arlit
# Processing Record 4 of set 9 | kalmunai
# Processing Record 5 of set 9 | gumia
# Processing Record 6 of set 9 | ahipara
# Processing Record 7 of set 9 | jieshi
# Processing Record 8 of set 9 | fougamou
# Processing Record 9 of set 9 | guymon
# Processing Record 10 of set 9 | lompoc
# Processing Record 11 of set 9 | anshun
# Processing Record 12 of set 9 | sikandra
# galgani not found
# Processing Record 14 of set 9 | hovd
# Processing Record 15 of set 9 | matara
# Processing Record 16 of set 9 | alice springs
# Processing Record 17 of set 9 | colomi
# Processing Record 18 of set 9 | ludvika
# Processing Record 19 of set 9 | puerto carreno
# Processing Record 20 of set 9 | port blair
# Processing Record 21 of set 9 | sao felix do xingu
# Processing Record 22 of set 9 | saint-francois
# Processing Record 23 of set 9 | ewa beach
# Processing Record 24 of set 9 | raduzhnyy
# palkaka not found
# Processing Record 26 of set 9 | pochutla
# Processing Record 27 of set 9 | husavik
# Processing Record 28 of set 9 | manzanillo
# chardara not found
# Processing Record 30 of set 9 | uvalde
# Processing Record 31 of set 9 | myitkyina
# Processing Record 32 of set 9 | uchiza
# acarau not found
# Processing Record 34 of set 9 | nizhniy kuranakh
# Processing Record 35 of set 9 | zhanaozen
# Processing Record 36 of set 9 | lander
# Processing Record 37 of set 9 | isilkul
# Processing Record 38 of set 9 | olavarria
# Processing Record 39 of set 9 | wasilla
# Processing Record 40 of set 9 | harindanga
# Processing Record 41 of set 9 | gari
# Processing Record 42 of set 9 | minab
# Processing Record 43 of set 9 | tooele
# Processing Record 44 of set 9 | pacific grove
# Processing Record 45 of set 9 | grand gaube
# sakakah not found
# Processing Record 47 of set 9 | beyneu
# Processing Record 48 of set 9 | east foothills
# Processing Record 49 of set 9 | tshikapa
# Processing Record 0 of set 10 | dongsheng
# Processing Record 1 of set 10 | weiser
# Processing Record 2 of set 10 | the valley
# Processing Record 3 of set 10 | simpang
# Processing Record 4 of set 10 | port hardy
# mutsamudu not found
# Processing Record 6 of set 10 | souillac
# Processing Record 7 of set 10 | olinda
# Processing Record 8 of set 10 | corn island
# aflu not found
# kofarnihon not found
# Processing Record 11 of set 10 | porto novo
# Processing Record 12 of set 10 | blue springs
# ngukurr not found
# Processing Record 14 of set 10 | zhigansk
# Processing Record 15 of set 10 | solenzo
# Processing Record 16 of set 10 | ialibu
# Processing Record 17 of set 10 | owando
# Processing Record 18 of set 10 | madang
# Processing Record 19 of set 10 | tumaco
# Processing Record 20 of set 10 | vila franca do campo
# Processing Record 21 of set 10 | alim
# Processing Record 22 of set 10 | barcelos
# Processing Record 23 of set 10 | rennes
# saleaula not found
# Processing Record 25 of set 10 | warrnambool
# Processing Record 26 of set 10 | dimitrovgrad
# Processing Record 27 of set 10 | winnemucca
# Processing Record 28 of set 10 | evensk
# Processing Record 29 of set 10 | ambikapur
# Processing Record 30 of set 10 | baghdad
# Processing Record 31 of set 10 | sao joao da barra
# Processing Record 32 of set 10 | marshall
# Processing Record 33 of set 10 | portland
# Processing Record 34 of set 10 | kindersley
# Processing Record 35 of set 10 | mitsamiouli
# falealupo not found
# gulshat not found
# Processing Record 38 of set 10 | altar
# Processing Record 39 of set 10 | caraubas
# Processing Record 40 of set 10 | baruun-urt
# Processing Record 41 of set 10 | broken hill
# Processing Record 42 of set 10 | coihaique
# Processing Record 43 of set 10 | moerai
# Processing Record 44 of set 10 | adrar
# Processing Record 45 of set 10 | toccoa
# Processing Record 46 of set 10 | martinsville
# Processing Record 47 of set 10 | rocky mountain house
# Processing Record 48 of set 10 | kadhan
# Processing Record 49 of set 10 | goundam
# Processing Record 0 of set 11 | banda aceh
# Processing Record 1 of set 11 | chakia
# Processing Record 2 of set 11 | santa rosalia
# Processing Record 3 of set 11 | madera
# Processing Record 4 of set 11 | monterey
# Processing Record 5 of set 11 | ubajara
# Processing Record 6 of set 11 | marsa matruh
# Processing Record 7 of set 11 | chifeng
# kembe not found
# Processing Record 9 of set 11 | nocupetaro
# Processing Record 10 of set 11 | plouzane
# Processing Record 11 of set 11 | deder
# Processing Record 12 of set 11 | hartselle
# Processing Record 13 of set 11 | baykit
# Processing Record 14 of set 11 | tucson
# Processing Record 15 of set 11 | eskil
# Processing Record 16 of set 11 | dharchula
# Processing Record 17 of set 11 | awjilah
# Processing Record 18 of set 11 | nelson bay
# Processing Record 19 of set 11 | kiruna
# Processing Record 20 of set 11 | ugoofaaru
# Processing Record 21 of set 11 | panama city
# Processing Record 22 of set 11 | kanniyakumari
# Processing Record 23 of set 11 | balkanabat
# bolungarvik not found
# Processing Record 25 of set 11 | akdepe
# Processing Record 26 of set 11 | macenta
# Processing Record 27 of set 11 | westport
# Processing Record 28 of set 11 | petropavlovsk-kamchatskiy
# Processing Record 29 of set 11 | darab
# Processing Record 30 of set 11 | lavrentiya
# Processing Record 31 of set 11 | hatillo
# Processing Record 32 of set 11 | ust-kuyga
# Processing Record 33 of set 11 | hualmay
# sayanskiy not found
# Processing Record 35 of set 11 | antofagasta
# suao not found
# Processing Record 37 of set 11 | pervomayskiy
# Processing Record 38 of set 11 | salistea de sus
# Processing Record 39 of set 11 | chillan
# Processing Record 40 of set 11 | romitan
# zhaocheng not found
# Processing Record 42 of set 11 | tingo maria
# Processing Record 43 of set 11 | chadan
# Processing Record 44 of set 11 | santa ana
# Processing Record 45 of set 11 | pennadam
# Processing Record 46 of set 11 | zeya
# jyvaskyla not found
# Processing Record 48 of set 11 | nyrob
# Processing Record 49 of set 11 | morehead
# Processing Record 0 of set 12 | batagay
# Processing Record 1 of set 12 | zverinogolovskoye
# Processing Record 2 of set 12 | kaduy
# kapoeta not found
# bolshegrivskoye not found
# Processing Record 5 of set 12 | staryy oskol
# Processing Record 6 of set 12 | kloulklubed
# Processing Record 7 of set 12 | miri
# Processing Record 8 of set 12 | oranjemund
# Processing Record 9 of set 12 | moree
# Processing Record 10 of set 12 | jalu
# Processing Record 11 of set 12 | namatanai
# Processing Record 12 of set 12 | diego de almagro
# Processing Record 13 of set 12 | esperance
# Processing Record 14 of set 12 | nkwerre
# Processing Record 15 of set 12 | vyselki
# Processing Record 16 of set 12 | aketi
# yambio not found
# Processing Record 18 of set 12 | ustupo
# kazalinsk not found
# Processing Record 20 of set 12 | srivardhan
# Processing Record 21 of set 12 | laguna
# Processing Record 22 of set 12 | salvador
# Processing Record 23 of set 12 | college
# Processing Record 24 of set 12 | patitirion
# Processing Record 25 of set 12 | ahuimanu
# Processing Record 26 of set 12 | matadi
# Processing Record 27 of set 12 | tromso
# Processing Record 28 of set 12 | las vegas
# Processing Record 29 of set 12 | veinticinco de diciembre
# Processing Record 30 of set 12 | kodinsk
# Processing Record 31 of set 12 | barabinsk
# olafsvik not found
# Processing Record 33 of set 12 | bud
# Processing Record 34 of set 12 | tezu
# Processing Record 35 of set 12 | camacha
# Processing Record 36 of set 12 | nurota
# Processing Record 37 of set 12 | igrim
# Processing Record 38 of set 12 | bara
# Processing Record 39 of set 12 | henties bay
# Processing Record 40 of set 12 | okha
# Processing Record 41 of set 12 | nautla
# Processing Record 42 of set 12 | horta
# Processing Record 43 of set 12 | altus
# Processing Record 44 of set 12 | bilma
# Processing Record 45 of set 12 | aden
# Processing Record 46 of set 12 | rawson
# Processing Record 47 of set 12 | kalevala
# Processing Record 48 of set 12 | sistranda
# Processing Record 49 of set 12 | xai-xai
# andevoranto not found
# Processing Record 1 of set 13 | sibolga
# Processing Record 2 of set 13 | storforshei
# Processing Record 3 of set 13 | holly hill
# Processing Record 4 of set 13 | yarmouth
# Processing Record 5 of set 13 | gornopravdinsk
# Processing Record 6 of set 13 | san juan del sur
# Processing Record 7 of set 13 | naze
# tumannyy not found
# Processing Record 9 of set 13 | luwuk
# Processing Record 10 of set 13 | chicama
# Processing Record 11 of set 13 | narsaq
# Processing Record 12 of set 13 | xiamen
# Processing Record 13 of set 13 | pingliang
# Processing Record 14 of set 13 | mazagao
# Processing Record 15 of set 13 | deputatskiy
#
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# check number of cities found
count_city_found
# Out:
# 546

# %%
# check number of cities not found
count_city_not_found
# Out:
# 70

# %%
# check number of length of dataframe
cities_df.count()
# Out:
# city    616
# dtype: int64

# %%
# check if all cities were processed (count_city_found + count_city_not_found = length(cities))
count_city_found + count_city_not_found
# Out:
# 616

# %%
# check first data inside city_weather
city_weather[0]
# Out:
# {'coord': {'lon': -11.33, 'lat': 8.35},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 20.88,
#   'pressure': 1012.99,
#   'humidity': 99,
#   'temp_min': 20.88,
#   'temp_max': 20.88,
#   'sea_level': 1012.99,
#   'grnd_level': 972.02},
#  'wind': {'speed': 0.99, 'deg': 262.76},
#  'clouds': {'all': 99},
#  'dt': 1563765137,
#  'sys': {'message': 0.0052,
#   'country': 'SL',
#   'sunrise': 1563777331,
#   'sunset': 1563822458},
#  'timezone': 0,
#  'id': 2410312,
#  'name': 'Barma',
#  'cod': 200}

# %%
# check last data inside city_weather
city_weather[-1]
# Out:
# {'coord': {'lon': 139.9, 'lat': 69.3},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 1.58,
#   'pressure': 1021.31,
#   'humidity': 92,
#   'temp_min': 1.58,
#   'temp_max': 1.58,
#   'sea_level': 1021.31,
#   'grnd_level': 956.09},
#  'wind': {'speed': 3.19, 'deg': 320.105},
#  'clouds': {'all': 100},
#  'dt': 1563765433,
#  'sys': {'message': 0.0075, 'country': 'RU', 'sunrise': 0, 'sunset': 0},
#  'timezone': 36000,
#  'id': 2028164,
#  'name': 'Deputatskiy',
#  'cod': 200}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# extract Temperature, humidity, lat,lon, country, wind speed, date, city,max. temperature
temperature = []
humidity    = []
lat         = []
long        = []
cloudiness  = []
wind_speed  = []
country     = []
dt          = []
city_name   = []

for i in range (count_city_found):
    lat.append(city_weather[i]["coord"]["lat"])
    long.append(city_weather[i]["coord"]["lon"])
    temperature.append(city_weather[i]["main"]["temp_max"])
    humidity.append(city_weather[i]["main"]["humidity"])
    cloudiness.append(city_weather[i]["clouds"]["all"])
    country.append(city_weather[i]["sys"]["country"])
    wind_speed.append(city_weather[i]["wind"]["speed"])
    dt.append(city_weather[i]["dt"])
    city_name.append(city_weather[i]["name"])
print("done")
# Out:
# done

# %%
# Create dataframe from extracted data
weather_data_df = pd.DataFrame({
                     'City' : city_name , 
                     'Cloudiness':cloudiness,
                     'Country':country ,
                     'Date':dt, 
                     'Humidity':humidity, 
                     "Lat":lat, 
                     "Lon":long, 
                     "Max temp": temperature, 
                     "Wind speed":wind_speed 
                    })

weather_data_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lon  \
# 0           Barma          99      SL  1563765137        99   8.35  -11.33
# 1           Pevek         100      RU  1563765137        95  69.70  170.27
# 2         Isangel          75      VU  1563765138        53 -19.55  169.27
# 3  Port Elizabeth           1      US  1563765138        79  39.31  -74.98
# 4       Busselton         100      AU  1563765138        45 -33.64  115.35
#
#    Max temp  Wind speed
# 0     20.88        0.99
# 1      0.88        9.63
# 2     24.00        5.10
# 3     32.00        2.10
# 4     15.56        7.66

# %%
# Save in CVS file 
#  without the Pandas index, but with the header
weather_data_df.to_csv(output_data_file, index=False, header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# check date (dt in Unix time)
dt_format = []
for i in range (count_city_found):
    dt_format.append(datetime.utcfromtimestamp(dt[i]).strftime('%Y-%m-%d %H:%M:%S'))

# %%
# found the date 

dt_format = pd.Series(dt_format) # transform the dt list into serie to use split()

date = []

# extract date in Year-month-day format
for i in range (count_city_found): 
    date.append(dt_format.str.split(" ")[i][0])

# %%
# checl if date is unique
date= pd.Series(date)
day = date.unique()[0]
day
# Out:
# '2019-07-22'

# %%
# extract lat and temp to prepare the plot
x = weather_data_df["Lat"]
y = weather_data_df["Max temp"]

# %%
min_temp = weather_data_df["Max temp"].min()
max_temp = weather_data_df["Max temp"].max()

# %%
# determine the minmax of the temperature axis
margin_temp = 5  # margin value
axis_temp_max = round(max_temp/10)*10 + margin_temp
axis_temp_min = round(min_temp/10)*10 - margin_temp

# %%
fig1=plt.figure(1)
plt.scatter(x,y, marker="o", facecolors="lightblue", edgecolors="black", alpha=0.75)
plt.xlim(-90,90)  # range of lat [-90:90]
plt.ylim(axis_temp_min,axis_temp_max)

plt.xlabel("Latitude (deg)")
plt.ylabel("Max. temperature (F)")
plt.grid()

plt.title(f"City Latitude vs Max Temperature ({day})")
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig(fig_file1)

# %%
plt.close(fig1)

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# assign humidity to y
y = weather_data_df["Humidity"]

# %%
min_humidity = weather_data_df["Humidity"].min()
max_humidity = weather_data_df["Humidity"].max()

# %%
# determine the minmax of the humidity axis
margin_temp = 5  # margin value
axis_humidity_max = round(max_humidity/10)*10 + margin_temp
axis_humidity_min = 0 # can't be negative

# %%
fig2=plt.figure(2)

plt.scatter(x,y, marker="o", facecolors="lightblue", edgecolors="black", alpha=0.75)
plt.xlim(-90,90)  # range of lat [-90:90]
plt.ylim(axis_humidity_min,axis_humidity_max)

plt.xlabel("Latitude (deg)")
plt.ylabel("Humidity (%)")
plt.grid()

plt.title(f"City Latitude vs Humidity ({day})")
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig(fig_file2)
plt.close(fig2)

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# assign cloudiness to y
y = weather_data_df["Cloudiness"]

# %%
min_cloud = weather_data_df["Cloudiness"].min()
max_cloud = weather_data_df["Cloudiness"].max()

# %%
# determine the minmax of the cloudiness axis
margin_temp = 5  # margin value
axis_cloud_max = round(max_cloud/10)*10 + margin_temp
axis_cloud_min = 0 # can't be negative

# %%
fig3=plt.figure(3)

plt.scatter(x,y, marker="o", facecolors="lightblue", edgecolors="black", alpha=0.75)
plt.xlim(-90,90)  # range of lat [-90:90]
plt.ylim(axis_cloud_min,axis_cloud_max)

plt.xlabel("Latitude (deg)")
plt.ylabel("Cloudiness (%)")
plt.grid()

plt.title(f"City Latitude vs Cloudiness ({day})")
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig(fig_file3)
plt.close(fig3)

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# assign cloudiness to y
y = weather_data_df["Wind speed"]

# %%
min_wind = weather_data_df["Wind speed"].min()
max_wind = weather_data_df["Wind speed"].max()

# %%
# determine the minmax of the cloudiness axis
margin_temp = 5  # margin value
axis_wind_max = round(max_wind/10)*10 
axis_wind_min = 0 # can't be negative

# %%
fig4=plt.figure(4)

plt.scatter(x,y, marker="o", facecolors="lightblue", edgecolors="black", alpha=0.75)
plt.xlim(-90,90)  # range of lat [-90:90]
plt.ylim(axis_wind_min,axis_wind_max)

plt.xlabel("Latitude (deg)")
plt.ylabel("Wind speed (mph)")
plt.grid()

plt.title(f"City Latitude vs Wind speed ({day})")
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig(fig_file4)
plt.close(fig4)
